# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Impact of extreme values on mean & median:

# %%
np.mean([1,2,3,8,10])
# Out:
# np.float64(4.8)

# %%
np.median([1,2,3,8,10])
# Out:
# np.float64(3.0)
